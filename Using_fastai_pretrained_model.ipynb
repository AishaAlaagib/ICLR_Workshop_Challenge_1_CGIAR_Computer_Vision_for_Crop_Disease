# %%
# !pip3 install pretrainedmodels
# Out:
# Requirement already satisfied: pretrainedmodels in /home/aisha/miniconda3/lib/python3.6/site-packages (0.7.4)
# Requirement already satisfied: torch in /home/aisha/miniconda3/lib/python3.6/site-packages (from pretrainedmodels) (1.4.0)
# Requirement already satisfied: munch in /home/aisha/miniconda3/lib/python3.6/site-packages (from pretrainedmodels) (2.5.0)
# Requirement already satisfied: torchvision in /home/aisha/miniconda3/lib/python3.6/site-packages (from pretrainedmodels) (0.2.2)
# Requirement already satisfied: tqdm in /home/aisha/miniconda3/lib/python3.6/site-packages (from pretrainedmodels) (4.43.0)
# Requirement already satisfied: six in /home/aisha/miniconda3/lib/python3.6/site-packages (from munch->pretrainedmodels) (1.11.0)
# Requirement already satisfied: numpy in /home/aisha/miniconda3/lib/python3.6/site-packages (from torchvision->pretrainedmodels) (1.16.4)
# Requirement already satisfied: pillow>=4.1.1 in /home/aisha/miniconda3/lib/python3.6/site-packages (from torchvision->pretrainedmodels) (5.4.1)
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# Fast AI doesn't read in .jfif by default, so we need this.
#!sudo apt install imagemagick
# !cd test; mogrify -format jpg *.jfif
# !cd train/healthy_wheat; mogrify -format jpg *.jfif  
# !cd train/leaf_rust; mogrify -format jpg *.jfif  
# !cd train/stem_rust; mogrify -format jpg *.jfif

# %% [markdown]
# # Using Pretrainedmodels

# %%
import pretrainedmodels
import os

# %% [markdown]
# # Mount to Drive

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /bin/bash: line 0: cd: too many arguments

# %%
#cd gdrive/My\ Drive
# Out:
# /content/gdrive/My Drive

# %%
#cd ICLR/
# Out:
# /content/gdrive/My Drive/ICLR

# %%
os.listdir("train")
# Out:
# ['stem_rust', 'leaf_rust', 'healthy_wheat']

# %%
os.listdir("train/healthy_wheat")[:10]
# Out:
# ['QUBMQI.jpg',
#  '6BNDTJ.jpg',
#  'OV44OF.jpg',
#  'U0P84E.jfif',
#  'SVTYF9.jpg',
#  '3C82ZM.jpg',
#  'WGJ7NJ.jfif',
#  '3FAKM2.jpg',
#  '0PFX47.jpg',
#  '5WTM0W.jpg']

# %%
os.listdir("test")[:10]
# Out:
# ['ZOXDKA.jfif',
#  '1R1HEY.JPG',
#  'GU40NL.JPG',
#  'AD54KD.jpg',
#  '8NRRD6.jpg',
#  '43AW2T.jfif',
#  'OVOLCQ.JPG',
#  'M9RQNE.jpg',
#  'LT0KA0.jpg',
#  'CA6QE3.jfif']

# %%
# !pip install --upgrade fastai
# Out:
# Collecting fastai
#   Using cached https://files.pythonhosted.org/packages/f5/e4/a7025bf28f303dbda0f862c09a7f957476fa92c9271643b4061a81bb595f/fastai-1.0.60-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: numexpr in /home/aisha/miniconda3/lib/python3.6/site-packages (from fastai) (2.7.1)
# Requirement already satisfied, skipping upgrade: requests in /home/aisha/miniconda3/lib/python3.6/site-packages (from fastai) (2.22.0)
# Requirement already satisfied, skipping upgrade: scipy in /home/aisha/miniconda3/lib/python3.6/site-packages (from fastai) (1.2.1)
# Requirement already satisfied, skipping upgrade: spacy>=2.0.18 in /home/aisha/miniconda3/lib/python3.6/site-packages (from fastai) (2.2.4)
# Requirement already satisfied, skipping upgrade: torchvision in /home/aisha/miniconda3/lib/python3.6/site-packages (from fastai) (0.2.2)
# Requirement already satisfied, skipping upgrade: bottleneck in /home/aisha/miniconda3/lib/python3.6/site-packages (from fastai) (1.3.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in /home/aisha/miniconda3/lib/python3.6/site-packages (from fastai) (1.16.4)
# Requirement already satisfied, skipping upgrade: pandas in /home/aisha/miniconda3/lib/python3.6/site-packages (from fastai) (0.24.2)
# Requirement already satisfied, skipping upgrade: packaging in /home/aisha/miniconda3/lib/python3.6/site-packages/packaging-19.0-py3.6.egg (from fastai) (19.0)
# Collecting torch>=1.0.0
#   Using cached https://files.pythonhosted.org/packages/24/19/4804aea17cd136f1705a5e98a00618cb8f6ccc375ad8bfa437408e09d058/torch-1.4.0-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied, skipping upgrade: nvidia-ml-py3 in /home/aisha/miniconda3/lib/python3.6/site-packages (from fastai) (7.352.0)
# Requirement already satisfied, skipping upgrade: Pillow in /home/aisha/miniconda3/lib/python3.6/site-packages (from fastai) (5.4.1)
# Requirement already satisfied, skipping upgrade: pyyaml in /home/aisha/miniconda3/lib/python3.6/site-packages (from fastai) (5.1)
# Requirement already satisfied, skipping upgrade: beautifulsoup4 in /home/aisha/miniconda3/lib/python3.6/site-packages (from fastai) (4.8.2)
# Requirement already satisfied, skipping upgrade: matplotlib in /home/aisha/miniconda3/lib/python3.6/site-packages (from fastai) (3.0.2)
# Requirement already satisfied, skipping upgrade: dataclasses; python_version < "3.7" in /home/aisha/miniconda3/lib/python3.6/site-packages (from fastai) (0.7)
# Requirement already satisfied, skipping upgrade: fastprogress>=0.2.1 in /home/aisha/miniconda3/lib/python3.6/site-packages (from fastai) (0.2.2)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /home/aisha/miniconda3/lib/python3.6/site-packages (from requests->fastai) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /home/aisha/miniconda3/lib/python3.6/site-packages (from requests->fastai) (2.7)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/aisha/miniconda3/lib/python3.6/site-packages (from requests->fastai) (2019.11.28)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/aisha/miniconda3/lib/python3.6/site-packages (from requests->fastai) (1.25.7)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in /home/aisha/miniconda3/lib/python3.6/site-packages (from spacy>=2.0.18->fastai) (2.0.3)
# Requirement already satisfied, skipping upgrade: wasabi<1.1.0,>=0.4.0 in /home/aisha/miniconda3/lib/python3.6/site-packages (from spacy>=2.0.18->fastai) (0.6.0)
# Requirement already satisfied, skipping upgrade: blis<0.5.0,>=0.4.0 in /home/aisha/miniconda3/lib/python3.6/site-packages (from spacy>=2.0.18->fastai) (0.4.1)
# Requirement already satisfied, skipping upgrade: preshed<3.1.0,>=3.0.2 in /home/aisha/miniconda3/lib/python3.6/site-packages (from spacy>=2.0.18->fastai) (3.0.2)
# Requirement already satisfied, skipping upgrade: plac<1.2.0,>=0.9.6 in /home/aisha/miniconda3/lib/python3.6/site-packages (from spacy>=2.0.18->fastai) (1.1.3)
# Requirement already satisfied, skipping upgrade: catalogue<1.1.0,>=0.0.7 in /home/aisha/miniconda3/lib/python3.6/site-packages (from spacy>=2.0.18->fastai) (1.0.0)
# Requirement already satisfied, skipping upgrade: setuptools in /home/aisha/miniconda3/lib/python3.6/site-packages (from spacy>=2.0.18->fastai) (45.1.0)
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in /home/aisha/miniconda3/lib/python3.6/site-packages (from spacy>=2.0.18->fastai) (1.0.2)
# Requirement already satisfied, skipping upgrade: thinc==7.4.0 in /home/aisha/miniconda3/lib/python3.6/site-packages (from spacy>=2.0.18->fastai) (7.4.0)
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.38.0 in /home/aisha/miniconda3/lib/python3.6/site-packages (from spacy>=2.0.18->fastai) (4.43.0)
# Requirement already satisfied, skipping upgrade: srsly<1.1.0,>=1.0.2 in /home/aisha/miniconda3/lib/python3.6/site-packages (from spacy>=2.0.18->fastai) (1.0.2)
# Requirement already satisfied, skipping upgrade: six in /home/aisha/miniconda3/lib/python3.6/site-packages (from torchvision->fastai) (1.11.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.0 in /home/aisha/miniconda3/lib/python3.6/site-packages (from pandas->fastai) (2.7.5)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /home/aisha/miniconda3/lib/python3.6/site-packages (from pandas->fastai) (2018.7)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /home/aisha/miniconda3/lib/python3.6/site-packages (from packaging->fastai) (2.3.1)
# Requirement already satisfied, skipping upgrade: soupsieve>=1.2 in /home/aisha/miniconda3/lib/python3.6/site-packages (from beautifulsoup4->fastai) (2.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /home/aisha/miniconda3/lib/python3.6/site-packages (from matplotlib->fastai) (1.0.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home/aisha/miniconda3/lib/python3.6/site-packages (from matplotlib->fastai) (0.10.0)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=0.20; python_version < "3.8" in /home/aisha/miniconda3/lib/python3.6/site-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.0.18->fastai) (1.5.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /home/aisha/miniconda3/lib/python3.6/site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.0.18->fastai) (3.1.0)
# Installing collected packages: torch, fastai
#   Found existing installation: torch 0.3.1
#     Uninstalling torch-0.3.1:
#       Successfully uninstalled torch-0.3.1
#   Found existing installation: fastai 0.7.0
#     Uninstalling fastai-0.7.0:
#       Successfully uninstalled fastai-0.7.0
# Successfully installed fastai-1.0.60 torch-1.4.0
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import fastai
from fastai.imports import *

# %%
from fastai import *
from fastai.vision import *

import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import auc,roc_curve

from math import floor

# %% [markdown]
# # Load the data

# %%
train_path = "train"
test_path = "test"
def get_labels(file_path): 
    dir_name = os.path.dirname(file_path)
    split_dir_name = dir_name.split("/")
    dir_levels = len(split_dir_name)
    label  = split_dir_name[dir_levels - 1]
    return(label)
from glob import glob
imagePatches = glob("train/*/*.*", recursive=True)
imagePatches[0:10]
path=""
from fastai.vision import *

# %%
get_labels("../input/train/train/healthy_wheat/'M9RQNE.jpg'")
# Out:
# 'healthy_wheat'

# %%
path=""
from fastai.vision import *
# transform_kwargs = {"do_flip": True,
#                      "flip_vert": True}
# #                     "max_rotate": 180,
# #                     #"max_zoom": 1.1,
# #                     #"max_lighting": 0.2,
# #                     #"max_warp": 0.2,
# #                     #"p_affine": 0.75,
# #                     #"p_lighting": 0.7,
# #                     "xtra_tfms" : zoom_crop(scale=(0.5, 1.5), do_rand=True)}
        
# tfms = vision.get_transforms(**transform_kwargs)
tfms = get_transforms() 
data = ImageDataBunch.from_name_func(path, imagePatches, label_func=get_labels,  size=500, 
                                     bs=16,num_workers=0,test = test_path,ds_tfms=tfms
                                  ).normalize(imagenet_stats)

# %%
# data = ImageDataBunch.from_folder('', train = 'train', test = 'test', valid_pct= 0.2 , ds_tfms = get_transforms(), size = 500,bs= 16, num_workers=0).normalize(imagenet_stats)

# %%
#data.show_batch(rows=3, figsize=(8,8))

# %% [markdown]
# # Using se_resnext50_32x4d with the pretrained model

# %%
ath=""
import pretrainedmodels as pm
model_name = 'se_resnext50' # 'vgg_16_2'
# pretrained = 'imagenet' if pretrained else None
_base_arch = lambda arg: pm.se_resnext50_32x4d(pretrained= 'imagenet')
learner = vision.cnn_learner(data, 
                             base_arch = _base_arch, 
                             pretrained = True, 
                             metrics = accuracy).mixup()

# %% [markdown]
# # first model name 'model-501'

# %%
learner.lr_find()
learner.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 10:05<10:05]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.671884</td>
#       <td>#na#</td>
#       <td>10:05</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='29' class='' max='59', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       49.15% [29/59 01:34<01:37 6.0489]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learner.unfreeze()
lr=2e-4
learner.fit_one_cycle(5, lr)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.319842</td>
#       <td>0.539881</td>
#       <td>0.784810</td>
#       <td>05:34</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.872610</td>
#       <td>0.683714</td>
#       <td>0.848101</td>
#       <td>04:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.632147</td>
#       <td>0.442271</td>
#       <td>0.881857</td>
#       <td>04:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.419122</td>
#       <td>0.534777</td>
#       <td>0.848101</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.334990</td>
#       <td>0.437540</td>
#       <td>0.886076</td>
#       <td>03:58</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.save('model-last-501')

# %%
interpreter = ClassificationInterpretation.from_learner(learner)
interpreter.most_confused(min_val=2)
# Out:
# [('leaf_rust', 'stem_rust', 10),
#  ('stem_rust', 'leaf_rust', 6),
#  ('healthy_wheat', 'leaf_rust', 5),
#  ('healthy_wheat', 'stem_rust', 4)]

# %% [markdown]
# #  load the first model and run it again 'model-502'

# %%
learner.lr_find()
learner.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 03:21<03:21]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.507808</td>
#       <td>#na#</td>
#       <td>03:21</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='59', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/59 00:00<00:00]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learner.load('model-last-501')
learner.unfreeze()
learner.fit_one_cycle(10,2e-6)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.217168</td>
#       <td>0.441023</td>
#       <td>0.881857</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.240596</td>
#       <td>0.443933</td>
#       <td>0.898734</td>
#       <td>03:58</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.256892</td>
#       <td>0.417599</td>
#       <td>0.894515</td>
#       <td>04:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.256890</td>
#       <td>0.431598</td>
#       <td>0.902954</td>
#       <td>04:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.222888</td>
#       <td>0.411642</td>
#       <td>0.890295</td>
#       <td>04:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.240508</td>
#       <td>0.432184</td>
#       <td>0.877637</td>
#       <td>04:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.190731</td>
#       <td>0.442515</td>
#       <td>0.894515</td>
#       <td>04:03</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.218803</td>
#       <td>0.435537</td>
#       <td>0.898734</td>
#       <td>04:02</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.201634</td>
#       <td>0.428105</td>
#       <td>0.894515</td>
#       <td>04:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.181793</td>
#       <td>0.438721</td>
#       <td>0.873418</td>
#       <td>03:59</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.save('model-last-502')

# %%
learner.recorder.plot_losses()

# %%
interpreter = ClassificationInterpretation.from_learner(learner)
interpreter.most_confused(min_val=2)
# Out:
# [('stem_rust', 'leaf_rust', 14),
#  ('healthy_wheat', 'leaf_rust', 6),
#  ('leaf_rust', 'stem_rust', 5),
#  ('healthy_wheat', 'stem_rust', 3)]

# %%
learner.lr_find()
learner.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 03:02<03:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.502237</td>
#       <td>#na#</td>
#       <td>03:02</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='29' class='' max='59', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       49.15% [29/59 01:29<01:32 4.7071]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learner.load('model-last-502')
learner.unfreeze()
lr = 2e-5
learner.fit_one_cycle(6, lr)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.801992</td>
#       <td>1.079276</td>
#       <td>0.493671</td>
#       <td>03:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.486156</td>
#       <td>0.722278</td>
#       <td>0.679325</td>
#       <td>03:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.223843</td>
#       <td>0.546005</td>
#       <td>0.797468</td>
#       <td>03:43</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.001203</td>
#       <td>0.465972</td>
#       <td>0.835443</td>
#       <td>03:46</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.864730</td>
#       <td>0.459627</td>
#       <td>0.818565</td>
#       <td>03:46</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.835093</td>
#       <td>0.461001</td>
#       <td>0.822785</td>
#       <td>03:45</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.save('model-last-503')

# %%
learner.recorder.plot_losses()

# %%
interp = ClassificationInterpretation.from_learner(learner)
interp.most_confused(min_val=2)
# Out:
# [('leaf_rust', 'stem_rust', 3), ('stem_rust', 'leaf_rust', 2)]

# %% [markdown]
# # submit 'model-502'

# %%
#learner.recorder.plot_losses()

# %%
learner.load('model-502')

interp = ClassificationInterpretation.from_learner(learner)

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
#interp = ClassificationInterpretation.from_learner(learner)
interp.most_confused(min_val=2)
# Out:
# []

# %%
import os
preds,y = learner.TTA(ds_type=DatasetType.Test)

submission = pd.DataFrame({'ID': [s.split('.')[0] for s in os.listdir('test')  if s.split('.')[1] != 'jfif']})
for i, c in enumerate(learner.data.classes):
  submission[c] = preds[:,i]

submission = submission[['ID', 'leaf_rust', 'stem_rust', 'healthy_wheat']] # Get same order as sample sub
submission.head()
# Out:
#        ID  leaf_rust  stem_rust  healthy_wheat
# 0  SS11ZQ   0.022007   0.970436       0.007557
# 1  GU40NL   0.002882   0.996965       0.000153
# 2  ROPN18   0.008736   0.974651       0.016612
# 3  99LHT9   0.016020   0.968035       0.015946
# 4  AD54KD   0.561924   0.362609       0.075467

# %%
submission.to_csv("resnet50-model502-secondround.csv", index=False)

# %% [markdown]
# # submit 'model-503'

# %%
learner.load('model-503')
#learner.export()
#learner.recorder.plot_losses()
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (952 items)
# x: ImageList
# Image (3, 448, 448),Image (3, 448, 448),Image (3, 448, 448),Image (3, 448, 448),Image (3, 448, 448)
# y: CategoryList
# stem_rust,stem_rust,stem_rust,stem_rust,stem_rust
# Path: .;
#
# Valid: LabelList (237 items)
# x: ImageList
# Image (3, 448, 448),Image (3, 448, 448),Image (3, 448, 448),Image (3, 448, 448),Image (3, 448, 448)
# y: CategoryList
# leaf_rust,stem_rust,leaf_rust,stem_rust,healthy_wheat
# Path: .;
#
# Test: LabelList (610 items)
# x: ImageList
# Image (3, 448, 448),Image (3, 448, 448),Image (3, 448, 448),Image (3, 448, 448),Image (3, 448, 448)
# y: EmptyLabelList
# ,,,,
# Path: ., model=Sequential(
#   (0): Sequential(
#     (0): Sequential(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (pool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     )
#     (1): Sequential(
#       (0): SEResNeXtBottleneck(
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): SEResNeXtBottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (2): SEResNeXtBottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (2): Sequential(
#       (0): SEResNeXtBottleneck(
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): SEResNeXtBottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (2): SEResNeXtBottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (3): SEResNeXtBottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (3): Sequential(
#       (0): SEResNeXtBottleneck(
#         (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (2): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (3): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (4): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (5): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (4): Sequential(
#       (0): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): SEResNeXtBottleneck(
#         (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (2): SEResNeXtBottleneck(
#         (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=4096, out_features=512, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=3, bias=True)
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x7fbc89c8cbf8>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[], layer_groups=[Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (4): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU(inplace=True)
#   (11): AdaptiveAvgPool2d(output_size=1)
#   (12): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#   (13): ReLU(inplace=True)
#   (14): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#   (15): Sigmoid()
#   (16): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (17): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (18): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (19): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (21): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (22): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (23): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): ReLU(inplace=True)
#   (25): AdaptiveAvgPool2d(output_size=1)
#   (26): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#   (27): ReLU(inplace=True)
#   (28): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#   (29): Sigmoid()
#   (30): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (31): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (32): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (33): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (34): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (35): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (36): ReLU(inplace=True)
#   (37): AdaptiveAvgPool2d(output_size=1)
#   (38): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#   (39): ReLU(inplace=True)
#   (40): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#   (41): Sigmoid()
#   (42): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (43): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (44): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#   (45): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (46): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (47): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (48): ReLU(inplace=True)
#   (49): AdaptiveAvgPool2d(output_size=1)
#   (50): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#   (51): ReLU(inplace=True)
#   (52): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#   (53): Sigmoid()
#   (54): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (55): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (56): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (57): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (58): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (59): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (60): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (61): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (62): ReLU(inplace=True)
#   (63): AdaptiveAvgPool2d(output_size=1)
#   (64): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#   (65): ReLU(inplace=True)
#   (66): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#   (67): Sigmoid()
#   (68): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (69): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (70): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (71): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (72): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (73): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (74): ReLU(inplace=True)
#   (75): AdaptiveAvgPool2d(output_size=1)
#   (76): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#   (77): ReLU(inplace=True)
#   (78): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#   (79): Sigmoid()
#   (80): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (81): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (82): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (83): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (84): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (85): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (86): ReLU(inplace=True)
#   (87): AdaptiveAvgPool2d(output_size=1)
#   (88): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#   (89): ReLU(inplace=True)
#   (90): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#   (91): Sigmoid()
#   (92): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (93): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (94): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#   (95): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (96): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (97): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (98): ReLU(inplace=True)
#   (99): AdaptiveAvgPool2d(output_size=1)
#   (100): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (101): ReLU(inplace=True)
#   (102): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (103): Sigmoid()
#   (104): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (105): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (106): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (107): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (108): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (109): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (110): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (111): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (112): ReLU(inplace=True)
#   (113): AdaptiveAvgPool2d(output_size=1)
#   (114): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (115): ReLU(inplace=True)
#   (116): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (117): Sigmoid()
#   (118): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (119): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (120): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (121): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (122): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (123): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (124): ReLU(inplace=True)
#   (125): AdaptiveAvgPool2d(output_size=1)
#   (126): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (127): ReLU(inplace=True)
#   (128): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (129): Sigmoid()
#   (130): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (131): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (132): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (133): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (134): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (135): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (136): ReLU(inplace=True)
#   (137): AdaptiveAvgPool2d(output_size=1)
#   (138): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (139): ReLU(inplace=True)
#   (140): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (141): Sigmoid()
#   (142): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (143): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (144): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (145): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (146): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (147): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (148): ReLU(inplace=True)
#   (149): AdaptiveAvgPool2d(output_size=1)
#   (150): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (151): ReLU(inplace=True)
#   (152): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (153): Sigmoid()
#   (154): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (155): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (156): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (157): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (158): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (159): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (160): ReLU(inplace=True)
#   (161): AdaptiveAvgPool2d(output_size=1)
#   (162): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#   (163): ReLU(inplace=True)
#   (164): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (165): Sigmoid()
#   (166): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (167): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (168): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#   (169): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (170): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (171): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (172): ReLU(inplace=True)
#   (173): AdaptiveAvgPool2d(output_size=1)
#   (174): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#   (175): ReLU(inplace=True)
#   (176): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#   (177): Sigmoid()
#   (178): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (179): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (180): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (181): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (182): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (183): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (184): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (185): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (186): ReLU(inplace=True)
#   (187): AdaptiveAvgPool2d(output_size=1)
#   (188): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#   (189): ReLU(inplace=True)
#   (190): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#   (191): Sigmoid()
#   (192): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (193): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (194): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (195): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (196): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (197): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (198): ReLU(inplace=True)
#   (199): AdaptiveAvgPool2d(output_size=1)
#   (200): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#   (201): ReLU(inplace=True)
#   (202): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#   (203): Sigmoid()
# ), Sequential(
#   (0): AdaptiveAvgPool2d(output_size=1)
#   (1): AdaptiveMaxPool2d(output_size=1)
#   (2): Flatten()
#   (3): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (4): Dropout(p=0.25, inplace=False)
#   (5): Linear(in_features=4096, out_features=512, bias=True)
#   (6): ReLU(inplace=True)
#   (7): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): Dropout(p=0.5, inplace=False)
#   (9): Linear(in_features=512, out_features=3, bias=True)
# )], add_time=True, silent=False)

# %%
interp = ClassificationInterpretation.from_learner(learner)
interp.most_confused(min_val=2)
# Out:
# [('leaf_rust', 'stem_rust', 2)]

# %%
preds,y = learner.TTA(ds_type=DatasetType.Test)
import os

submission = pd.DataFrame({'ID': [s.split('.')[0] for s in os.listdir('test')  if s.split('.')[1] != 'jfif']})
for i, c in enumerate(learner.data.classes):
  submission[c] = preds[:,i]

submission = submission[['ID', 'leaf_rust', 'stem_rust', 'healthy_wheat']] # Get same order as sample sub
submission.head()
# Out:
#        ID  leaf_rust  stem_rust  healthy_wheat
# 0  SS11ZQ   0.048676   0.939649       0.011675
# 1  GU40NL   0.002800   0.996724       0.000477
# 2  ROPN18   0.068828   0.907479       0.023694
# 3  99LHT9   0.038478   0.941145       0.020377
# 4  AD54KD   0.720895   0.219673       0.059432

# %%
submission.to_csv("resnet50-model503.csv", index=False)

# %% [markdown]
# # using model_502 to do model504

# %%
learner.load('model-last-502')
learner.lr_find()
learner.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 03:24<03:24]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.464345</td>
#       <td>#na#</td>
#       <td>03:24</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='59', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       5.08% [3/59 00:10<03:18 0.7247]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learner.load('model-last-502')
learner.unfreeze()
learner.fit_one_cycle(6, 2e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.215431</td>
#       <td>0.426181</td>
#       <td>0.894515</td>
#       <td>04:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.223793</td>
#       <td>0.451524</td>
#       <td>0.881857</td>
#       <td>04:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.200611</td>
#       <td>0.444536</td>
#       <td>0.890295</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.175211</td>
#       <td>0.420506</td>
#       <td>0.898734</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.132239</td>
#       <td>0.445054</td>
#       <td>0.894515</td>
#       <td>04:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.131884</td>
#       <td>0.435418</td>
#       <td>0.894515</td>
#       <td>04:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.save('model-last-504')

# %%
learner.load('model-last-504')
interpreter = ClassificationInterpretation.from_learner(learner)
interpreter.most_confused(min_val=2)
# Out:
# [('stem_rust', 'leaf_rust', 9),
#  ('leaf_rust', 'stem_rust', 6),
#  ('healthy_wheat', 'leaf_rust', 5),
#  ('healthy_wheat', 'stem_rust', 4)]

# %%
#learner.recorder.plot_losses()

# %%
preds,y = learner.TTA(ds_type=DatasetType.Test)
import os

submission = pd.DataFrame({'ID': [s.split('.')[0] for s in os.listdir('test')  if s.split('.')[1] != 'jfif']})
for i, c in enumerate(learner.data.classes):
  submission[c] = preds[:,i]

submission = submission[['ID', 'leaf_rust', 'stem_rust', 'healthy_wheat']] # Get same order as sample sub
submission.head()
# Out:
#        ID  leaf_rust  stem_rust  healthy_wheat
# 0  SS11ZQ   0.005423   0.990750       0.003828
# 1  GU40NL   0.001363   0.998025       0.000612
# 2  ROPN18   0.000988   0.993506       0.005506
# 3  99LHT9   0.000263   0.982715       0.017022
# 4  AD54KD   0.508580   0.460125       0.031295

# %%
submission.to_csv("resnet50-model504.csv", index=False)

# %% [markdown]
# # using mode504 to do model-505

# %%
tfms = get_transforms() 
data = ImageDataBunch.from_name_func(path, imagePatches, label_func=get_labels,  size=520, 
                                     bs=8,num_workers=0,test = test_path,ds_tfms=tfms
                                  ).normalize(imagenet_stats)

# %%
# def se_resnext50_32x4d(pretrained=False):
#     pretrained = 'imagenet' if pretrained else None
#     model = pretrainedmodels.se_resnext50_32x4d(pretrained=pretrained)
#     return model
import pretrainedmodels as pm
model_name = 'se_resnext50' # 'vgg_16_2'
# pretrained = 'imagenet' if pretrained else None
_base_arch = lambda arg: pm.se_resnext50_32x4d(pretrained='imagenet')
learner = vision.cnn_learner(data, 
                             base_arch = _base_arch, 
                             pretrained = True, 
                             metrics = accuracy)

# %%
learner.load('model-last-504')
learner.lr_find()
learner.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='119', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.72% [8/119 00:14<03:22 0.1390]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learner.load('model-last-504')
learner.unfreeze() 
learner.fit_one_cycle(6, 2e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.367344</td>
#       <td>0.111842</td>
#       <td>0.970464</td>
#       <td>04:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.335481</td>
#       <td>0.121676</td>
#       <td>0.970464</td>
#       <td>04:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.343367</td>
#       <td>0.143699</td>
#       <td>0.953587</td>
#       <td>04:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.348953</td>
#       <td>0.119232</td>
#       <td>0.962025</td>
#       <td>04:18</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.316263</td>
#       <td>0.110042</td>
#       <td>0.966245</td>
#       <td>04:16</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.263408</td>
#       <td>0.119893</td>
#       <td>0.966245</td>
#       <td>04:17</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.save('model-last-505')
learner.unfreeze()
learner.load('model-last-505')
interpreter = ClassificationInterpretation.from_learner(learner)
interpreter.most_confused(min_val=2)
# Out:
# [('stem_rust', 'leaf_rust', 4), ('healthy_wheat', 'leaf_rust', 2)]

# %%
preds,y = learner.TTA(ds_type=DatasetType.Test)
import os

submission = pd.DataFrame({'ID': [s.split('.')[0] for s in os.listdir('test')  if s.split('.')[1] != 'jfif']})
for i, c in enumerate(learner.data.classes):
  submission[c] = preds[:,i]

submission = submission[['ID', 'leaf_rust', 'stem_rust', 'healthy_wheat']] # Get same order as sample sub
submission.head()

# %%
submission.to_csv("resnet50-model505.csv", index=False)

# %% [markdown]
# # using model 505 with imgsize 520 and bs =8

# %%
learner.load('model-last-505')
learner.unfreeze()
learner.fit_one_cycle(10, 2e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.257523</td>
#       <td>0.122823</td>
#       <td>0.970464</td>
#       <td>04:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.269515</td>
#       <td>0.105695</td>
#       <td>0.962025</td>
#       <td>04:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.312999</td>
#       <td>0.111917</td>
#       <td>0.962025</td>
#       <td>04:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.254656</td>
#       <td>0.138020</td>
#       <td>0.945148</td>
#       <td>04:12</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.244142</td>
#       <td>0.145859</td>
#       <td>0.957806</td>
#       <td>04:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.276912</td>
#       <td>0.135279</td>
#       <td>0.962025</td>
#       <td>04:12</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.228029</td>
#       <td>0.142795</td>
#       <td>0.953587</td>
#       <td>04:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.220482</td>
#       <td>0.173138</td>
#       <td>0.962025</td>
#       <td>04:12</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.223582</td>
#       <td>0.160378</td>
#       <td>0.962025</td>
#       <td>04:12</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.217990</td>
#       <td>0.153028</td>
#       <td>0.962025</td>
#       <td>04:13</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.save('model-last-506')
interpreter = ClassificationInterpretation.from_learner(learner)
interpreter.most_confused(min_val=2)
# Out:
# [('stem_rust', 'leaf_rust', 5), ('leaf_rust', 'stem_rust', 2)]

# %%
preds,y = learner.TTA(ds_type=DatasetType.Test)
import os

submission = pd.DataFrame({'ID': [s.split('.')[0] for s in os.listdir('test')  if s.split('.')[1] != 'jfif']})
for i, c in enumerate(learner.data.classes):
  submission[c] = preds[:,i]

submission = submission[['ID', 'leaf_rust', 'stem_rust', 'healthy_wheat']] # Get same order as sample sub
submission.head()

# %%
submission.to_csv("resnet50-model506.csv", index=False)

# %% [markdown]
# # continue training

# %%
learner.load('model-last-506')
learner.unfreeze()
learner.fit_one_cycle(8, 2e-5)

# %%
learner.save('model-last-508')
interpreter = ClassificationInterpretation.from_learner(learner)
interpreter.most_confused(min_val=2)
preds8,y = learner.TTA(ds_type=DatasetType.Test)

# %%
submission = pd.DataFrame({'ID': [s.split('.')[0] for s in os.listdir('test')  if s.split('.')[1] != 'jfif']})
for i, c in enumerate(learner.data.classes):
  submission[c] = preds8[:,i]

submission = submission[['ID', 'leaf_rust', 'stem_rust', 'healthy_wheat']] # Get same order as sample sub
submission.head()
submission.to_csv("resnet50-model508.csv", index=False)

# %%
learner.load('model-last-508')
learner.unfreeze()
learner.fit_one_cycle(10, 2e-5)
learner.save('model-last-509')
interpreter = ClassificationInterpretation.from_learner(learner)
interpreter.most_confused(min_val=2)

# %%
reds9,y = learner.TTA(ds_type=DatasetType.Test)
submission = pd.DataFrame({'ID': [s.split('.')[0] for s in os.listdir('test')  if s.split('.')[1] != 'jfif']})
for i, c in enumerate(learner.data.classes):
  submission[c] = reds5[:,i]

submission = submission[['ID', 'leaf_rust', 'stem_rust', 'healthy_wheat']] # Get same order as sample sub
submission.head()
submission.to_csv("resnet50-model509.csv", index=False)

# %% [markdown]
# # Ensamble method

# %%
learner.unfreeze()
learner.load('model-last-502')
interpreter = ClassificationInterpretation.from_learner(learner)
interpreter.most_confused(min_val=2)
# Out:
# [('healthy_wheat', 'leaf_rust', 3), ('stem_rust', 'leaf_rust', 3)]

# %%
preds2,y = learner.TTA(ds_type=DatasetType.Test)

# %%
learner.unfreeze()
learner.load('model-last-504')
interpreter = ClassificationInterpretation.from_learner(learner)
interpreter.most_confused(min_val=2)
# Out:
# [('healthy_wheat', 'leaf_rust', 2),
#  ('leaf_rust', 'stem_rust', 2),
#  ('stem_rust', 'leaf_rust', 2)]

# %%
preds4,y = learner.TTA(ds_type=DatasetType.Test)

# %%
learner.unfreeze()
learner.load('model-last-505')
interpreter = ClassificationInterpretation.from_learner(learner)
interpreter.most_confused(min_val=2)
# Out:
# [('stem_rust', 'leaf_rust', 4), ('healthy_wheat', 'leaf_rust', 2)]

# %%
preds5,y = learner.TTA(ds_type=DatasetType.Test)

# %%
learner.unfreeze()
learner.load('model-last-506')
interpreter = ClassificationInterpretation.from_learner(learner)
interpreter.most_confused(min_val=2)
# Out:
# [('stem_rust', 'leaf_rust', 5), ('leaf_rust', 'stem_rust', 2)]

# %%
preds6,y = learner.TTA(ds_type=DatasetType.Test)

# %%
learner.unfreeze()
learner.load('model-last-508')
interpreter = ClassificationInterpretation.from_learner(learner)
interpreter.most_confused(min_val=2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-46-6094c4efccdd> in <module>()
#       1 learner.unfreeze()
# ----> 2 learner.load('model-last-508')
#       3 interpreter = ClassificationInterpretation.from_learner(learner)
#       4 interpreter.most_confused(min_val=2)
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in load(self, file, device, strict, with_opt, purge, remove_module)
#     267         source = self.path/self.model_dir/f'{file}.pth' if is_pathlike(file) else file
#     268         distrib_barrier()
# --> 269         state = torch.load(source, map_location=device)
#     270         if set(state.keys()) == {'model', 'opt'}:
#     271             model_state = state['model']
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     523         pickle_load_args['encoding'] = 'utf-8'
#     524
# --> 525     with _open_file_like(f, 'rb') as opened_file:
#     526         if _is_zipfile(opened_file):
#     527             with _open_zipfile_reader(f) as opened_zipfile:
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     210 def _open_file_like(name_or_buffer, mode):
#     211     if _is_path(name_or_buffer):
# --> 212         return _open_file(name_or_buffer, mode)
#     213     else:
#     214         if 'w' in mode:
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     191 class _open_file(_opener):
#     192     def __init__(self, name, mode):
# --> 193         super(_open_file, self).__init__(open(name, mode))
#     194
#     195     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/model-last-508.pth'

# %%
preds8,y = learner.TTA(ds_type=DatasetType.Test)

# %%
learner.unfreeze()
learner.load('model-last-509')
interpreter = ClassificationInterpretation.from_learner(learner)
interpreter.most_confused(min_val=2)

# %%
preds9,y = learner.TTA(ds_type=DatasetType.Test)

# %%
#preds,y = learner.TTA(ds_type=DatasetType.Test)

# %%
preds = ( preds4 + preds5 + preds6 )/3

# %%
import os

submission = pd.DataFrame({'ID': [s.split('.')[0] for s in os.listdir('test')  if s.split('.')[1] != 'jfif']})
for i, c in enumerate(learner.data.classes):
  submission[c] = preds[:,i]

submission = submission[['ID', 'leaf_rust', 'stem_rust', 'healthy_wheat']] # Get same order as sample sub
submission.head()
# Out:
#        ID  leaf_rust  stem_rust  healthy_wheat
# 0  SS11ZQ   0.001352   0.991395       0.007253
# 1  GU40NL   0.000277   0.999261       0.000462
# 2  ROPN18   0.009720   0.989176       0.001104
# 3  99LHT9   0.014137   0.912292       0.073571
# 4  AD54KD   0.334152   0.656587       0.009261

# %%
submission.to_csv("resnet50-model546.csv", index=False)

# %%
preds = ( preds4 + preds5 + preds6 + preds8 +preds9)/5

# %%
import os

submission = pd.DataFrame({'ID': [s.split('.')[0] for s in os.listdir('test')  if s.split('.')[1] != 'jfif']})
for i, c in enumerate(learner.data.classes):
  submission[c] = preds[:,i]

submission = submission[['ID', 'leaf_rust', 'stem_rust', 'healthy_wheat']] # Get same order as sample sub
submission.head()

# %%
submission.to_csv("resnet50-model-averageall.csv", index=False)

# %% [markdown]
# # train resnet34

# %%
# !pip3 install pydicom
# !pip3 install pretrainedmodels
# Out:
# Collecting pydicom
#   Downloading https://files.pythonhosted.org/packages/c0/ea/b05a0051a579acc8026e46a889354774a0da9d31f42aaa1af35a1f0e4a43/pydicom-1.4.1-py2.py3-none-any.whl (35.1MB)
#      |████████████████████████████████| 35.1MB 88kB/s
# Installing collected packages: pydicom
# Successfully installed pydicom-1.4.1
# Collecting pretrainedmodels
#   Downloading https://files.pythonhosted.org/packages/84/0e/be6a0e58447ac16c938799d49bfb5fb7a80ac35e137547fc6cee2c08c4cf/pretrainedmodels-0.7.4.tar.gz (58kB)
#      |████████████████████████████████| 61kB 2.0MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from pretrainedmodels) (1.4.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (from pretrainedmodels) (0.5.0)
# Collecting munch
#   Downloading https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from pretrainedmodels) (4.28.1)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision->pretrainedmodels) (6.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision->pretrainedmodels) (1.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision->pretrainedmodels) (1.17.5)
# Building wheels for collected packages: pretrainedmodels
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-cp36-none-any.whl size=60962 sha256=f01ba2917624027a8f947ae3121c8ad135a62ddcd8ced179c07587ebc78c7162
#   Stored in directory: /root/.cache/pip/wheels/69/df/63/62583c096289713f22db605aa2334de5b591d59861a02c2ecd
# Successfully built pretrainedmodels
# Installing collected packages: munch, pretrainedmodels
# Successfully installed munch-2.5.0 pretrainedmodels-0.7.4

# %%
import numpy as np
import pandas as pd
import os
import fastai
from fastai.vision import *
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt  
import pydicom
import torchvision.models as models
from tqdm import tqdm
from glob import glob
from fastai.vision import *
number_epochs=5
import pretrainedmodels as pm

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
#json_file = '/content/gdrive/My Drive/Colab Notebooks/data/kaggle.json'
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
cd ICLR/
# Out:
# /content/gdrive/My Drive/ICLR

# %%
# !pip3 install pydicom

# %%
train_path = "train"
test_path = "test"
def get_labels(file_path): 
    dir_name = os.path.dirname(file_path)
    split_dir_name = dir_name.split("/")
    dir_levels = len(split_dir_name)
    label  = split_dir_name[dir_levels - 1]
    return(label)
imagePatches = glob("train/*/*.*", recursive=True)
imagePatches[0:10]
path=""
tfms = get_transforms()

# %%
# data

# %%
data = ImageDataBunch.from_name_func(path, imagePatches, label_func=get_labels,  size=224, 
                                  bs=16,num_workers=0,test = test_path,ds_tfms=tfms
                              ).normalize(imagenet_stats)

# %%
# learn = cnn_learner(data, base_arch= , metrics=[accuracy])

# %%
_base_arch = lambda arg: pm.se_resnext50_32x4d(pretrained='imagenet')
learn50 = vision.cnn_learner(data, 
                             base_arch = _base_arch, 
                             pretrained = True, 
                             metrics = accuracy)

# %%
learn50.lr_find()
learn50.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 11:14<11:14]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.557411</td>
#       <td>#na#</td>
#       <td>11:14</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='29' class='' max='59', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       49.15% [29/59 00:59<01:01 5.2561]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn50.fit_one_cycle(8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.278485</td>
#       <td>0.719470</td>
#       <td>0.772152</td>
#       <td>04:43</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.078086</td>
#       <td>0.581459</td>
#       <td>0.835443</td>
#       <td>02:30</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.848679</td>
#       <td>0.518269</td>
#       <td>0.810127</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.583347</td>
#       <td>0.414319</td>
#       <td>0.839662</td>
#       <td>02:28</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.518862</td>
#       <td>0.275908</td>
#       <td>0.890295</td>
#       <td>02:28</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.405811</td>
#       <td>0.279405</td>
#       <td>0.881857</td>
#       <td>02:28</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.361004</td>
#       <td>0.299607</td>
#       <td>0.898734</td>
#       <td>02:31</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.368741</td>
#       <td>0.259020</td>
#       <td>0.898734</td>
#       <td>02:26</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn50.save('stage-1-50')

# %%
learn50.load('stage-1-50')
learn50.unfreeze()
learn50.fit_one_cycle(5, 2e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.351677</td>
#       <td>0.253767</td>
#       <td>0.907173</td>
#       <td>02:35</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.277138</td>
#       <td>0.243361</td>
#       <td>0.928270</td>
#       <td>02:32</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.277590</td>
#       <td>0.197830</td>
#       <td>0.924051</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.257211</td>
#       <td>0.222787</td>
#       <td>0.928270</td>
#       <td>02:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.227819</td>
#       <td>0.197416</td>
#       <td>0.932489</td>
#       <td>02:33</td>
#     </tr>
#   </tbody>
# </table>

# %%
# learn50.load('stage-1-50')

# %% [markdown]
# # submission

# %%
preds, test_labels = learn50.get_preds(ds_type=DatasetType.Test)

# %%
submission = pd.DataFrame({'ID': [s.split('.')[0] for s in os.listdir('test')  if s.split('.')[1] != 'jfif']})
for i, c in enumerate(learn50.data.classes):
  submission[c] = preds[:,i]

submission = submission[['ID', 'leaf_rust', 'stem_rust', 'healthy_wheat']] # Get same order as sample sub
submission.head()
# Out:
#        ID  leaf_rust  stem_rust  healthy_wheat
# 0  SS11ZQ   0.267580   0.712978       0.019442
# 1  GU40NL   0.011234   0.984456       0.004311
# 2  ROPN18   0.015238   0.984125       0.000637
# 3  99LHT9   0.001208   0.997912       0.000880
# 4  AD54KD   0.065004   0.901915       0.033081

# %%
submission.to_csv('submission_fastai.csv', index=False)

# %% [markdown]
# # increasing resolution

# %%
size = [224, 232, 248, 256, 272]
def get_data(sz, bs):
  data = ImageDataBunch.from_name_func(path, imagePatches, label_func=get_labels,  size=sz, 
                                  bs=bs,num_workers=0,test = test_path,ds_tfms=tfms
                              ).normalize(imagenet_stats)
  return data

# %% [markdown]
# # Using Default LR

# %%
learn50 = cnn_learner(get_data(8, int(2048/8)), models.resnet50, metrics=error_rate)
learn50.save('res50_0')
learn50.save('res50_224')
learn50 = cnn_learner(get_data(16, int(2048/16)), models.resnet50, metrics=error_rate).load('res50_224')
learn50.save('res50_232')
learn50 = cnn_learner(get_data(24, int(2048/24)), models.resnet50, metrics=error_rate).load('res50_232')
learn50.save('res50_240')
learn50 = cnn_learner(get_data(32, int(2048/32)), models.resnet50, metrics=error_rate).load('res50_240')
learn50.save('res50_248')
learn50 = cnn_learner(get_data(64, int(2048/64)), models.resnet50, metrics=error_rate).load('res50_248')
learn50.save('res50_256')
learn50 = cnn_learner(get_data(128, int(2048/128)), models.resnet50, metrics=error_rate).load('res50_256')
learn50.save('res50_264')
learn50 = cnn_learner(get_data(224, int(2048/224)), models.resnet50, metrics=error_rate).load('res50_264')
learn50.save('res50_272')

# %%
def train_model(sz, i):
  learn50 = cnn_learner(get_data(sz, int(2048/sz)), models.resnet50, metrics=[error_rate, accuracy]).load('res50_'+str(sz-8))
  learn50.fit_one_cycle(6*i)
  learn50.lr_find()
  learn50.recorder.plot()
  learn50.unfreeze()
  learn50.fit_one_cycle(2*i)
  learn50.save('res50_'+str(sz))

# %%
# ens = get_ensemble(3) # ens is a list type of object which will contain my three learnt model

# %%
train_model(224, 1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.397560</td>
#       <td>1.036695</td>
#       <td>0.274262</td>
#       <td>0.725738</td>
#       <td>03:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.055865</td>
#       <td>0.844410</td>
#       <td>0.282700</td>
#       <td>0.717300</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.781577</td>
#       <td>0.527121</td>
#       <td>0.202532</td>
#       <td>0.797468</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.608485</td>
#       <td>0.534449</td>
#       <td>0.227848</td>
#       <td>0.772152</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.489580</td>
#       <td>0.476474</td>
#       <td>0.198312</td>
#       <td>0.801688</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.477196</td>
#       <td>0.454423</td>
#       <td>0.172996</td>
#       <td>0.827004</td>
#       <td>03:03</td>
#     </tr>
#   </tbody>
# </table>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='75' class='' max='105', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       71.43% [75/105 01:52<00:44 0.7782]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.958605</td>
#       <td>0.803396</td>
#       <td>0.248945</td>
#       <td>0.751055</td>
#       <td>03:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.624476</td>
#       <td>0.479108</td>
#       <td>0.177215</td>
#       <td>0.822785</td>
#       <td>03:13</td>
#     </tr>
#   </tbody>
# </table>

# %%
train_model(232, 2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.516800</td>
#       <td>0.303924</td>
#       <td>0.118143</td>
#       <td>0.881857</td>
#       <td>03:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.557144</td>
#       <td>0.355389</td>
#       <td>0.118143</td>
#       <td>0.881857</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.573172</td>
#       <td>0.331778</td>
#       <td>0.122363</td>
#       <td>0.877637</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.567265</td>
#       <td>0.312790</td>
#       <td>0.113924</td>
#       <td>0.886076</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.605240</td>
#       <td>0.328556</td>
#       <td>0.143460</td>
#       <td>0.856540</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.465282</td>
#       <td>0.303677</td>
#       <td>0.118143</td>
#       <td>0.881857</td>
#       <td>03:09</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.440826</td>
#       <td>0.300719</td>
#       <td>0.135021</td>
#       <td>0.864979</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.450685</td>
#       <td>0.301495</td>
#       <td>0.101266</td>
#       <td>0.898734</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.418547</td>
#       <td>0.267692</td>
#       <td>0.109705</td>
#       <td>0.890295</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.431828</td>
#       <td>0.269045</td>
#       <td>0.101266</td>
#       <td>0.898734</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.299973</td>
#       <td>0.241205</td>
#       <td>0.084388</td>
#       <td>0.915612</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.329306</td>
#       <td>0.238233</td>
#       <td>0.075949</td>
#       <td>0.924051</td>
#       <td>03:07</td>
#     </tr>
#   </tbody>
# </table>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='80' class='' max='119', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       67.23% [80/119 01:46<00:52 1.0982]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.604969</td>
#       <td>0.656495</td>
#       <td>0.177215</td>
#       <td>0.822785</td>
#       <td>03:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.806801</td>
#       <td>0.507681</td>
#       <td>0.185654</td>
#       <td>0.814346</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.673181</td>
#       <td>0.496214</td>
#       <td>0.151899</td>
#       <td>0.848101</td>
#       <td>03:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.588880</td>
#       <td>0.438568</td>
#       <td>0.147679</td>
#       <td>0.852321</td>
#       <td>03:13</td>
#     </tr>
#   </tbody>
# </table>

# %%
train_model(240,3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.507025</td>
#       <td>0.235738</td>
#       <td>0.067511</td>
#       <td>0.932489</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.530476</td>
#       <td>0.243995</td>
#       <td>0.067511</td>
#       <td>0.932489</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.556603</td>
#       <td>0.231162</td>
#       <td>0.063291</td>
#       <td>0.936709</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.604715</td>
#       <td>0.316881</td>
#       <td>0.088608</td>
#       <td>0.911392</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.585242</td>
#       <td>0.264848</td>
#       <td>0.071730</td>
#       <td>0.928270</td>
#       <td>03:04</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.513649</td>
#       <td>0.222538</td>
#       <td>0.071730</td>
#       <td>0.928270</td>
#       <td>03:04</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.566236</td>
#       <td>0.239648</td>
#       <td>0.071730</td>
#       <td>0.928270</td>
#       <td>03:04</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.521311</td>
#       <td>0.289115</td>
#       <td>0.101266</td>
#       <td>0.898734</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.546785</td>
#       <td>0.227931</td>
#       <td>0.071730</td>
#       <td>0.928270</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.512967</td>
#       <td>0.197643</td>
#       <td>0.063291</td>
#       <td>0.936709</td>
#       <td>03:04</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.460234</td>
#       <td>0.252708</td>
#       <td>0.080169</td>
#       <td>0.919831</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.454549</td>
#       <td>0.344193</td>
#       <td>0.118143</td>
#       <td>0.881857</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.462233</td>
#       <td>0.217075</td>
#       <td>0.080169</td>
#       <td>0.919831</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.426768</td>
#       <td>0.235262</td>
#       <td>0.075949</td>
#       <td>0.924051</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.412118</td>
#       <td>0.226167</td>
#       <td>0.075949</td>
#       <td>0.924051</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.363737</td>
#       <td>0.228876</td>
#       <td>0.075949</td>
#       <td>0.924051</td>
#       <td>03:03</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.387082</td>
#       <td>0.225560</td>
#       <td>0.075949</td>
#       <td>0.924051</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.409124</td>
#       <td>0.230499</td>
#       <td>0.071730</td>
#       <td>0.928270</td>
#       <td>03:05</td>
#     </tr>
#   </tbody>
# </table>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='81' class='' max='119', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       68.07% [81/119 01:46<00:50 0.8002]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.407192</td>
#       <td>0.377312</td>
#       <td>0.139241</td>
#       <td>0.860759</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.750460</td>
#       <td>0.706404</td>
#       <td>0.286920</td>
#       <td>0.713080</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.748193</td>
#       <td>0.615364</td>
#       <td>0.227848</td>
#       <td>0.772152</td>
#       <td>03:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.603666</td>
#       <td>0.434417</td>
#       <td>0.151899</td>
#       <td>0.848101</td>
#       <td>03:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.542178</td>
#       <td>0.449066</td>
#       <td>0.160338</td>
#       <td>0.839662</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.436576</td>
#       <td>0.435830</td>
#       <td>0.160338</td>
#       <td>0.839662</td>
#       <td>03:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
train_model(248, 2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.459951</td>
#       <td>0.630065</td>
#       <td>0.151899</td>
#       <td>0.848101</td>
#       <td>15:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.465433</td>
#       <td>0.474909</td>
#       <td>0.168776</td>
#       <td>0.831224</td>
#       <td>15:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.467240</td>
#       <td>0.834491</td>
#       <td>0.151899</td>
#       <td>0.848101</td>
#       <td>15:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.497548</td>
#       <td>0.769334</td>
#       <td>0.118143</td>
#       <td>0.881857</td>
#       <td>15:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.478546</td>
#       <td>0.325955</td>
#       <td>0.084388</td>
#       <td>0.915612</td>
#       <td>15:20</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.451702</td>
#       <td>0.361178</td>
#       <td>0.118143</td>
#       <td>0.881857</td>
#       <td>15:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.411781</td>
#       <td>0.826306</td>
#       <td>0.160338</td>
#       <td>0.839662</td>
#       <td>15:08</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.418782</td>
#       <td>0.666972</td>
#       <td>0.113924</td>
#       <td>0.886076</td>
#       <td>15:11</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.381539</td>
#       <td>0.514130</td>
#       <td>0.092827</td>
#       <td>0.907173</td>
#       <td>15:06</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.353356</td>
#       <td>0.310784</td>
#       <td>0.088608</td>
#       <td>0.911392</td>
#       <td>15:08</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.375374</td>
#       <td>1.104808</td>
#       <td>0.143460</td>
#       <td>0.856540</td>
#       <td>15:13</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.400480</td>
#       <td>1.274156</td>
#       <td>0.151899</td>
#       <td>0.848101</td>
#       <td>15:11</td>
#     </tr>
#   </tbody>
# </table>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='80' class='' max='119', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       67.23% [80/119 09:06<04:26 0.8732]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.527150</td>
#       <td>1.783711</td>
#       <td>0.324895</td>
#       <td>0.675106</td>
#       <td>19:48</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.566235</td>
#       <td>0.874170</td>
#       <td>0.177215</td>
#       <td>0.822785</td>
#       <td>19:52</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.566915</td>
#       <td>0.386946</td>
#       <td>0.118143</td>
#       <td>0.881857</td>
#       <td>19:49</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.456192</td>
#       <td>0.338381</td>
#       <td>0.130802</td>
#       <td>0.869198</td>
#       <td>19:46</td>
#     </tr>
#   </tbody>
# </table>

# %%
interpreter = ClassificationInterpretation.from_learner(learn50)
interpreter.most_confused(min_val=2)
# Out:
# [('leaf_rust', 'healthy_wheat', 53),
#  ('stem_rust', 'healthy_wheat', 51),
#  ('leaf_rust', 'stem_rust', 34),
#  ('healthy_wheat', 'stem_rust', 14),
#  ('healthy_wheat', 'leaf_rust', 10),
#  ('stem_rust', 'leaf_rust', 9)]

# %%
sz = 256
i = 2
learn50 = cnn_learner(get_data(sz, int(2048/sz)), models.resnet50, metrics=[error_rate, accuracy]).load('res50_248')
learn50.fit_one_cycle(6*i, 2e-5)
learn50.lr_find()
learn50.recorder.plot()
learn50.unfreeze()
learn50.fit_one_cycle(2*i, 2e-5)
learn50.save('res50_'+str(sz))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.401742</td>
#       <td>0.305833</td>
#       <td>0.088608</td>
#       <td>0.911392</td>
#       <td>16:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.424522</td>
#       <td>0.316606</td>
#       <td>0.126582</td>
#       <td>0.873418</td>
#       <td>15:58</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.458012</td>
#       <td>0.326244</td>
#       <td>0.139241</td>
#       <td>0.860759</td>
#       <td>16:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.418020</td>
#       <td>0.303728</td>
#       <td>0.097046</td>
#       <td>0.902954</td>
#       <td>15:46</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.386903</td>
#       <td>0.295400</td>
#       <td>0.092827</td>
#       <td>0.907173</td>
#       <td>15:40</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.429133</td>
#       <td>0.299974</td>
#       <td>0.084388</td>
#       <td>0.915612</td>
#       <td>15:43</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.412115</td>
#       <td>0.288938</td>
#       <td>0.097046</td>
#       <td>0.902954</td>
#       <td>15:41</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.428840</td>
#       <td>0.293635</td>
#       <td>0.088608</td>
#       <td>0.911392</td>
#       <td>15:44</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.455398</td>
#       <td>0.286983</td>
#       <td>0.092827</td>
#       <td>0.907173</td>
#       <td>15:43</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.410268</td>
#       <td>0.297627</td>
#       <td>0.097046</td>
#       <td>0.902954</td>
#       <td>15:38</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.401651</td>
#       <td>0.305608</td>
#       <td>0.080169</td>
#       <td>0.919831</td>
#       <td>15:39</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.453913</td>
#       <td>0.295889</td>
#       <td>0.084388</td>
#       <td>0.915612</td>
#       <td>15:40</td>
#     </tr>
#   </tbody>
# </table>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='81' class='' max='119', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       68.07% [81/119 09:26<04:25 0.8854]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.418924</td>
#       <td>0.282239</td>
#       <td>0.084388</td>
#       <td>0.915612</td>
#       <td>20:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.453940</td>
#       <td>0.282029</td>
#       <td>0.101266</td>
#       <td>0.898734</td>
#       <td>20:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.391708</td>
#       <td>0.288938</td>
#       <td>0.097046</td>
#       <td>0.902954</td>
#       <td>20:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.387722</td>
#       <td>0.269017</td>
#       <td>0.080169</td>
#       <td>0.919831</td>
#       <td>20:11</td>
#     </tr>
#   </tbody>
# </table>

# %%
interpreter = ClassificationInterpretation.from_learner(learn50)
interpreter.most_confused(min_val=2)
# Out:
# [('leaf_rust', 'stem_rust', 10),
#  ('stem_rust', 'leaf_rust', 10),
#  ('healthy_wheat', 'stem_rust', 5),
#  ('leaf_rust', 'healthy_wheat', 3)]

# %%
learn50 = cnn_learner(get_data(420, 18), models.resnet50, metrics=error_rate).load('res50_256')
#learn50.save('best_420') 
learn50.fit_one_cycle(2)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='52', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/52 00:00<00:00]
#     </div>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-38-6442a90c6e13> in <module>()
#       1 learn50 = cnn_learner(get_data(420, 18), models.resnet50, metrics=error_rate).load('res50_256')
#       2 #learn50.save('best_420')
# ----> 3 learn50.fit_one_cycle(2)
#
# /usr/local/lib/python3.6/dist-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      21     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      22                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 23     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      24
#      25 def fit_fc(learn:Learner, tot_epochs:int=1, lr:float=defaults.lr,  moms:Tuple[float,float]=(0.95,0.85), start_pct:float=0.72,
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         else: self.opt.lr,self.opt.wd = lr,wd
#     199         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#     103
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      32     if opt is not None:
#      33         loss,skip_bwd = cb_handler.on_backward_begin(loss)
# ---> 34         if not skip_bwd:                     loss.backward()
#      35         if not cb_handler.on_backward_end(): opt.step()
#      36         if not cb_handler.on_step_end():     opt.zero_grad()
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn

# %%
sz = 420; i = 6
learn50 = vision.cnn_learner(get_data(sz, 18), models.resnet50, metrics=[error_rate, accuracy], 
                      callbacks=[SaveModelCallback(learn50, every='improvement', monitor='accuracy', name='best_420')])#.load('res50_256')

# %%
train_model(sz,2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-55-2c8e499447b3> in <module>()
# ----> 1 train_model(sz,2)
#
# <ipython-input-47-eba91fe6b8a1> in train_model(sz, i)
#       1 def train_model(sz, i):
# ----> 2   learn50 = cnn_learner(get_data(sz, int(2048/sz)), models.resnet50, metrics=[error_rate, accuracy]).load('res50_'+str(sz-8))
#       3   learn50.fit_one_cycle(6*i)
#       4   learn50.lr_find()
#       5   learn50.recorder.plot()
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in load(self, file, device, strict, with_opt, purge, remove_module)
#     267         source = self.path/self.model_dir/f'{file}.pth' if is_pathlike(file) else file
#     268         distrib_barrier()
# --> 269         state = torch.load(source, map_location=device)
#     270         if set(state.keys()) == {'model', 'opt'}:
#     271             model_state = state['model']
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     523         pickle_load_args['encoding'] = 'utf-8'
#     524
# --> 525     with _open_file_like(f, 'rb') as opened_file:
#     526         if _is_zipfile(opened_file):
#     527             with _open_zipfile_reader(f) as opened_zipfile:
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     210 def _open_file_like(name_or_buffer, mode):
#     211     if _is_path(name_or_buffer):
# --> 212         return _open_file(name_or_buffer, mode)
#     213     else:
#     214         if 'w' in mode:
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     191 class _open_file(_opener):
#     192     def __init__(self, name, mode):
# --> 193         super(_open_file, self).__init__(open(name, mode))
#     194
#     195     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/res50_412.pth'

# %%
learn50 = cnn_learner(get_data(sz, int(2048/sz)), models.resnet50, metrics=[error_rate, accuracy]).load('res50_248')
learn50.unfreeze()
learn50.fit_one_cycle(10) #2*i)
learn50.save('res50_'+str(sz))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/10 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='238', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/238 00:00<00:00]
#     </div>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-54-df3e37ef9594> in <module>()
#       1 learn50 = cnn_learner(get_data(sz, int(2048/sz)), models.resnet50, metrics=[error_rate, accuracy]).load('res50_248')
#       2 learn50.unfreeze()
# ----> 3 learn50.fit_one_cycle(10) #2*i)
#       4 learn50.save('res50_'+str(sz))
#
# /usr/local/lib/python3.6/dist-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      21     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      22                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 23     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      24
#      25 def fit_fc(learn:Learner, tot_epochs:int=1, lr:float=defaults.lr,  moms:Tuple[float,float]=(0.95,0.85), start_pct:float=0.72,
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         else: self.opt.lr,self.opt.wd = lr,wd
#     199         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#     103
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      32     if opt is not None:
#      33         loss,skip_bwd = cb_handler.on_backward_begin(loss)
# ---> 34         if not skip_bwd:                     loss.backward()
#      35         if not cb_handler.on_backward_end(): opt.step()
#      36         if not cb_handler.on_step_end():     opt.zero_grad()
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn

# %%
sz = 500; i = 7
learn50.load('best_224')
learn50.fit_one_cycle(2*i)
learn50.save('res50_'+str(sz))

# %% [markdown]
# # submission

# %%
learn50.load('best_224_1')
preds, test_labels = learn50.get_preds(ds_type=DatasetType.Test)

# %%
submission = pd.DataFrame({'ID': [s.split('.')[0] for s in os.listdir('test')  if s.split('.')[1] != 'jfif']})
for i, c in enumerate(learn50.data.classes):
  submission[c] = preds[:,i]

submission = submission[['ID', 'leaf_rust', 'stem_rust', 'healthy_wheat']] # Get same order as sample sub
submission.head()

# %%
submission.to_csv('submission_fastai_res50.csv', index=False)

# %% [markdown]
# # mixup

# %%
# learn50 = cnn_learner(get_data(224, 64), models.resnet50, metrics=[error_rate, accuracy], callbacks=[SaveModelCallback(learn50, every='improvement'
#             , monitor='accuracy', name='best_224_mixup')]).load('res50_224').mixup()

# %%
# learn50.fit(8)

# %%
# learn50.save('mixup_8')
# learn50.fit(5)
# learn50.save('mixup_5')

# %%
# learn50.unfreeze()
# learn50.fit_one_cycle(5)

# %%
# log_preds, test_labels = learn50.get_preds(ds_type=DatasetType.Test)

# %%
# submission = pd.DataFrame({'ID': [s.split('.')[0] for s in os.listdir('test')  if s.split('.')[1] != 'jfif']})
# for i, c in enumerate(learn50.data.classes):
#   submission[c] = preds[:,i]

# submission = submission[['ID', 'leaf_rust', 'stem_rust', 'healthy_wheat']] # Get same order as sample sub
# submission.head()

# %%
# submission.to_csv('submission_fastai_res50_mixup.csv', index=False)
